# %%
# Group 1
img1 = [
    "https://www.dropbox.com/scl/fi/c00ojckolq16w665wkzmu/1.zip?rlkey=n6wn4evbziztqv0r24lxhkaff&st=3m2n7vtn&dl=0"
]
img2 = [
    "https://www.dropbox.com/scl/fi/evtdixb10qy373285o0qp/2.zip?rlkey=qvg4i3g22rb5k8zcylj4s1zg8&st=u49bsray&dl=0",
    "https://www.dropbox.com/scl/fi/sp9i7cddc5plam0xe5va5/3.zip?rlkey=nbqwtx3ssfdwvsjxdwgxmt15r&st=ij2tt634&dl=0",
    "https://www.dropbox.com/scl/fi/jnrlwbpue8wyihm2cn83c/4.zip?rlkey=ywb3jf551veo1ssak3phdp1x7&st=1qmrugyp&dl=0",
    "https://www.dropbox.com/scl/fi/w40wn84utf5i05y87aew3/5.zip?rlkey=eeap46sfafolj7pjsaudniq53&st=72gjgsvx&dl=0"
]

# Group 2
img3 = [
    "https://www.dropbox.com/scl/fi/orokg9t3uut6cq1eb20xr/1.zip?rlkey=esqz3wzpvy6sbq9c6qtdo8g03&st=tuvwz5cd&dl=0"
]
img4 = [
    "https://www.dropbox.com/scl/fi/8nbotuilyjyikjoyk2ffx/2.zip?rlkey=uz7wtrgexcwscsivvo66verpv&st=eh32a59r&dl=0",
    "https://www.dropbox.com/scl/fi/o4kqyq9bhspa85km8fckh/3.zip?rlkey=y64z60qtdlulrvd3u9bdq4eug&st=4pncm2rz&dl=0",
    "https://www.dropbox.com/scl/fi/6s6uqr0s6x5n1pt5un0rt/4.zip?rlkey=r68j6znrjah9adi21n9aspuoj&st=cjcy6uwb&dl=0",
    "https://www.dropbox.com/scl/fi/mudh8xs60pz4d0o8nv2ko/5.zip?rlkey=9emu6759k64ze17o41ni3n4ws&st=abjrog9a&dl=0"
]

# Group 3
img5 = [
    "https://www.dropbox.com/scl/fi/y830ldn3pmcnp9jh1hh44/1.zip?rlkey=5x5d429c1ibg0azp5ybfe7ca4&st=ruchyihg&dl=0"
]
img6 = [
    "https://www.dropbox.com/scl/fi/bsy48s320z52ll0z2rhh5/2.zip?rlkey=bf68ui2spth6a5sbj9rrwrn89&st=gast31ad&dl=0",
    "https://www.dropbox.com/scl/fi/hycpmpeq5xk2vk6gdz2vc/3.zip?rlkey=j2y9x0vg8sg3tt8b62fbnebwr&st=4oojoxdj&dl=0",
    "https://www.dropbox.com/scl/fi/yn66wviq6neuopsh0cozw/4.zip?rlkey=3u7uwq1a81h1ozcvvuv8nchc4&st=yexfn9vu&dl=0",
    "https://www.dropbox.com/scl/fi/w4aldevgohbkzqss6kpoa/5.zip?rlkey=2418qjbkqefh7bgtkwrtq8vhl&st=j808fva5&dl=0"
]

# Group 4
img7 = [
    "https://www.dropbox.com/scl/fi/zme3tx10o4y2fmgl3i34h/1.zip?rlkey=76kq0zg9i0zgomppdsfhvm3hw&st=6hkopwdx&dl=0"
]
img8 = [
    "https://www.dropbox.com/scl/fi/bb6wvc5v7pwif03q1pbba/2.zip?rlkey=2cdibp51c4f3wx7b4mggpi0rc&st=s40f365b&dl=0",
    "https://www.dropbox.com/scl/fi/lzu8be28wsi6pfwbehlpn/3.zip?rlkey=vyiotyz7br506yip0a67q0868&st=07njum6a&dl=0",
    "https://www.dropbox.com/scl/fi/3hqxw17eid4600u2qiei4/4.zip?rlkey=21s12odujw93uefg8xfkktdm1&st=wj1es4ib&dl=0",
    "https://www.dropbox.com/scl/fi/tyx1hq8urzbk3gcu4uod4/5.zip?rlkey=npjvqned6cd1b9s1nxm7de51h&st=1h0dzgr7&dl=0"
]

# Group 5
img9 = [
    "https://www.dropbox.com/scl/fi/pvemzj939ztxgmwihqag9/1.zip?rlkey=eih77m3r74iaflmm2zc1xxxxd&st=9dcq2pzp&dl=0"
]
img10 = [
    "https://www.dropbox.com/scl/fi/iefzjf1xsraf8yhb1zg90/2.zip?rlkey=9mu46yzt9duz635luzacqarn8&st=6es1xo2g&dl=0",
    "https://www.dropbox.com/scl/fi/s6xi6ay4udk0nf0ftmhyr/3.zip?rlkey=3evi3tt63q6e3ywaszh8v1i9g&st=cfmpar8e&dl=0",
    "https://www.dropbox.com/scl/fi/eac7xe0vgkeu3kp626eo4/4.zip?rlkey=zj8y4ch8ry21utwrr5wgnal3s&st=r1v1xw2v&dl=0",
    "https://www.dropbox.com/scl/fi/tlzhb0q1swhzwh5v2jh9f/5.zip?rlkey=u566x2jc927a5eper4ubbuok0&st=vzifjhoc&dl=0"
]

# Group 6
img11 = [
    "https://www.dropbox.com/scl/fi/w4nygy1eta50gizi5rdr1/1.zip?rlkey=vqm3khnbkwzakgv844jaslqn9&st=sgsjue3x&dl=0"
]
img12 = [
    "https://www.dropbox.com/scl/fi/evqoz43y8kjdsdo5cy2x2/2.zip?rlkey=whcf8o6fhmafmwypy26w1075w&st=038ffa31&dl=0",
    "https://www.dropbox.com/scl/fi/329np9ysrkbw1zn7hf6t2/3.zip?rlkey=b31izef320x52m78hu8rft1i5&st=yurirt52&dl=0",
    "https://www.dropbox.com/scl/fi/ddesvdcweddbm4a5wku5t/4.zip?rlkey=vyceekomdhncwcmgqy7mhqb56&st=rlwij327&dl=0",
    "https://www.dropbox.com/scl/fi/vmknwsdu2zexa9na4dk7q/5.zip?rlkey=5yfp63n4a5jb0ff3xryguarhy&st=cpr6z7ra&dl=0"
]

# Group 7
img13 = [
    "https://www.dropbox.com/scl/fi/h8ot0j1p3xkh1s27qqkst/1.zip?rlkey=g7ajmw16s39weh0xxdsaufcrr&st=6d15vr8x&dl=0"
]
img14 = [
    "https://www.dropbox.com/scl/fi/ug2vevis9xrlo6wi92zr2/2.zip?rlkey=31bgxoj3wcoatnshurpc87wqg&st=a6ooo5rs&dl=0"
]

images_paths = [
    img14
]

# %%
# load model

# %%
for id, images_path in enumerate (images_paths):
    # !mkdir -p /kaggle/working/data
    # !mkdir -p /kaggle/working/NP
    
    for images in images_path:
        # !wget -O images.zip "{images}"
        # !unzip images.zip -d /kaggle/working/data
        # !rm images.zip
        
    root_folder = "/kaggle/working/data"
    
    for folder_name in natsorted(os.listdir(root_folder)):
        image_folder = os.path.join(root_folder, folder_name)

        image_files = natsorted([f for f in os.listdir(image_folder) if os.path.isfile(os.path.join(image_folder, f))])

        # chạy file ic.py
            
    # zip file kết quả
    
    # !rm -r /kaggle/working/data
    # !rm -r /kaggle/working/NP
